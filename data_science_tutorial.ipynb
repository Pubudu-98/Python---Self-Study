# %% [markdown]
# ## Python Concepts

# %%
name = 'Pubudu Piyumal'
age = 28
student_id = 2011034
GPA = 2.9
degree_title = 'BSc (HONS) Computer Science (Software Engineering)'

print('Details:', name, '|', age, '|', GPA, '|', student_id, '|', degree_title)
type(name), type(age), type(GPA)
# Out:
# Details: Pubudu Piyumal | 28 | 2.9 | 2011034 | BSc (HONS) Computer Science (Software Engineering)
# (str, int, float)

# %%
scores = [10, 20, 30, 40, 50]

print(scores[0])
print(scores[-1])
print(scores[1:4])
print(len(scores))
print(sum(scores))
type(scores)
# Out:
# 10
# 50
# [20, 30, 40]
# 5
# 150
# list

# %%
car = {
    'Model' : 'Swift',
    'YOM' : 2007,
    'Trim' : 'ZC11S'
}

type(car)
print(car['Model'])
print(car.keys())
print(car.values())
# Out:
# Swift
# dict_keys(['Model', 'YOM', 'Trim'])
# dict_values(['Swift', 2007, 'ZC11S'])

# %%
score = [55,60,80,45,40]
type(score)
# Out:
# list

# %%
for score in score:
    if score >= 55:
        print(score, 'Pass')
    else:
        print(score, 'Fail')
# Out:
# 55 Pass
# 60 Pass
# 80 Pass
# 45 Fail
# 40 Fail

# %%
#----Compound Interest Calculator----#

principal = 1000
rate = 0.007
years = 10

balance = principal

for year in range(1, years + 1):
    interest = balance * rate
    balance = balance + interest
    print('Year:', year, 'Balance:', balance)
# Out:
# Year: 1 Balance: 1007.0
# Year: 2 Balance: 1014.049
# Year: 3 Balance: 1021.147343
# Year: 4 Balance: 1028.295374401
# Year: 5 Balance: 1035.493442021807
# Year: 6 Balance: 1042.7418961159597
# Year: 7 Balance: 1050.0410893887713
# Year: 8 Balance: 1057.3913770144927
# Year: 9 Balance: 1064.793116653594
# Year: 10 Balance: 1072.2466684701692

# %%
def car (model):
    car_1 = model
    car_2 = model
    print(car_1, car_2)

Suzuki = 'Swift'
Mercedes = 'AMG A45S'

print(car(Suzuki))
print(car(Mercedes))
# Out:
# Swift Swift
# None
# AMG A45S AMG A45S
# None
